# %% [markdown]
# # Seaborn: distplot

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
cars = sns.load_dataset('mpg').dropna()

cars.shape
# Out:
# (392, 9)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.set_style('white')

# %% [markdown]
# ## Intro Visuals

# %%
hp = cars.horsepower.sample(100, random_state=100)

# %%
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)

# %%
plt.figure(figsize=(8,5))
sns.distplot(hp, rug=True, kde=False, hist=False, rug_kws={'lw': 2})

sns.despine(left=True)
plt.xlim(0, 280)
plt.xlabel('')
plt.yticks([])
plt.tight_layout();
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\3267405472.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(hp, rug=True, kde=False, hist=False, rug_kws={'lw': 2})

# %%
plt.figure(figsize=(8,5))
sns.distplot(hp, kde=False, hist_kws={'alpha': 1})

sns.despine(left=True)
plt.xlim(0, 280)
plt.xlabel('')
plt.yticks([])
plt.tight_layout();
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\2352659449.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(hp, kde=False, hist_kws={'alpha': 1})

# %%
plt.figure(figsize=(8,5))
sns.distplot(hp, hist=False, kde_kws={'lw': 5})

sns.despine(left=True)
plt.xlim(0, 280)
plt.xlabel('')
plt.yticks([])
plt.tight_layout();
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\1409037484.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(hp, hist=False, kde_kws={'lw': 5})

# %%
plt.figure(figsize=(8,5))
sns.distplot(hp, rug=True, kde_kws={"lw": 5}, rug_kws={'lw': 2} )

sns.despine(left=True)
plt.xlim(0, 280)
plt.xlabel('')
plt.yticks([])
plt.tight_layout();
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\3755680947.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(hp, rug=True, kde_kws={"lw": 5}, rug_kws={'lw': 2} )

# %% [markdown]
# ## Basics

# %%
sns.distplot(cars.weight);
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\1016146276.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight);

# %%
sns.distplot(cars.weight, kde=False);
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\3815730188.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight, kde=False);

# %%
sns.distplot(cars.weight, hist=False, rug=True);
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\65759181.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight, hist=False, rug=True);

# %% [markdown]
# ## Options

# %% [markdown]
# ### Bins

# %%
sns.distplot(cars.weight, bins=5);
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\257263574.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight, bins=5);

# %%
sns.distplot(cars.weight, bins=[1500, 2000, 2500, 3500, 5200]);
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\3165689108.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight, bins=[1500, 2000, 2500, 3500, 5200]);

# %% [markdown]
# ### Fit

# %%
from scipy.stats import skewnorm

sns.distplot(cars.weight, fit=skewnorm, kde=False);
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\336922953.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight, fit=skewnorm, kde=False);

# %% [markdown]
# ## Kwargs

# %% [markdown]
# ### hist_kws

# %%
sns.distplot(cars.weight, kde=False, hist_kws={'alpha': 1});
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\3044490359.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight, kde=False, hist_kws={'alpha': 1});

# %%
sns.distplot(cars.weight, kde=False, 
             hist_kws={'alpha': 1, 'histtype': 'stepfilled'});
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\3457470205.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight, kde=False,

# %% [markdown]
# ### kde_kws

# %%
sns.distplot(cars.weight, kde_kws={'lw': 5});
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\489962363.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight, kde_kws={'lw': 5});

# %%
sns.kdeplot(cars.weight, lw=5);

# %%
sns.distplot(cars.weight, kde_kws={'bw': 1000});
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\718734060.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight, kde_kws={'bw': 1000});
# C:\Users\xdxd2\AppData\Roaming\Python\Python310\site-packages\seaborn\distributions.py:2517: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=1000`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.13.0.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %% [markdown]
# ### rug_kws

# %%
sns.distplot(cars.weight, rug=True, rug_kws={'height': 0.15});
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\38586743.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight, rug=True, rug_kws={'height': 0.15});

# %%
sns.distplot(cars.weight, rug=True, 
             rug_kws={'height': 0.15, 'color': 'xkcd:navy'});
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\1055253814.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight, rug=True,

# %% [markdown]
# ## Styled Distplots

# %%
sns.set_style('white')

plt.figure(figsize=(8,5))
sns.distplot(cars.weight, 
             bins=20,
             kde_kws={"lw": 8, 'color':'xkcd:bluish green'},
             hist_kws={'alpha': 0.3, 'color':'gray'}
            )

sns.despine(left=True)
plt.xlabel('Weight (lbs)', fontsize=16, labelpad=15)
plt.yticks([])
plt.tight_layout()

plt.savefig('03dist_styleWeight_greenKDE.svg');
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\103723650.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight,

# %%
sns.set_style('white')

plt.figure(figsize=(8,5))
sns.distplot(cars.acceleration.sample(100, random_state=100), 
             rug=True,
             kde=False,
             hist_kws={'lw': 5, 
                       'linestyle': (0, (5, 1)),
                       'alpha': 1, 
                       'histtype':'step', 
                       'color':'xkcd:dark magenta'},
             rug_kws={'lw': 3,
                      'color':'xkcd:dark magenta'}
            )
sns.distplot(cars.acceleration.sample(100, random_state=100), 
             kde=False,
             hist_kws={'alpha': 0.1,
                       'histtype':'stepfilled', 
                       'color':'xkcd:dark magenta'},
            )

sns.despine(left=True)
plt.xlabel('')
plt.xticks([])
plt.yticks([])
plt.tight_layout()

plt.savefig('03dist_styleAcc_pink.svg');
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\1729671077.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.acceleration.sample(100, random_state=100),
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\1729671077.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.acceleration.sample(100, random_state=100),

# %%
import random
random.seed(11)

data = [random.gauss(2, 0.75) for _ in range(50)]
data.extend([random.gauss(-2, 0.75) for _ in range(50)])

sns.set_style('whitegrid')

plt.figure(figsize=(8,5))
sns.distplot(data, 
             rug=True,
             hist=False, 
             color='green',
             kde_kws={'lw':4, 'shade':True, 'bw':.5},
             rug_kws={'lw':2}
            )

sns.despine()
plt.xlabel('')
plt.tight_layout()

#plt.savefig('03dist_styleRand_greenKDErug.svg');
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\1394951190.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,
# C:\Users\xdxd2\AppData\Roaming\Python\Python310\site-packages\seaborn\distributions.py:2517: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=0.5`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.13.0.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\xdxd2\AppData\Roaming\Python\Python310\site-packages\seaborn\distributions.py:2517: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
sns.set_style('darkgrid')

data = [random.gauss(2, 0.75) for _ in range(100)]
data.extend([random.gauss(-2, 0.75) for _ in range(50)])

plt.figure(figsize=(8,5))
sns.distplot(data, 
             hist_kws={'histtype': 'stepfilled', 
                       'alpha':0.7, 'color':'xkcd:carolina blue'},
             kde_kws={'lw':8,'color':'xkcd:navy'}
            )

sns.despine()
plt.xlabel('')
plt.tight_layout()

#plt.savefig('03dist_styleRand_carolina.svg');
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_34976\629339632.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,
