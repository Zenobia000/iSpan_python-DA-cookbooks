# %% [markdown]
# # Seaborn: scatterplot

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
diamonds = sns.load_dataset('diamonds')

diamonds.shape
# Out:
# (53940, 10)

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds = diamonds[
            diamonds.cut.isin(['Premium', 'Good']) & 
            diamonds.color.isin(['D', 'F', 'J'])
            ].sample(n=100, random_state=22)

diamonds.shape
# Out:
# (100, 10)

# %% [markdown]
# ## Intro Visuals

# %%
import pandas as pd
import numpy as np

# %%
sns.set_style('white')
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)

# %%
blue, orange, green, red = sns.color_palette()[:4]

# %%
pts_x = [1] #, 2, 1.5, 4, 3, 2.5, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1] #, 3, 2.5, 3, 3.5, 2, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(x=pts_x, y=pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic1.svg')

# %%
pts_x = [1, 2] #, 1.5, 4, 3, 2.5, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3] #, 2.5, 3, 3.5, 2, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(x = pts_x, y = pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic2.svg')

# %%
pts_x = [1, 2, 1.5] #, 4, 3, 2.5, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3, 2.5] #, 3, 3.5, 2, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(x = pts_x, y = pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic3.svg')

# %%
pts_x = [1, 2, 1.5, 4, 3, 2.5] #, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3, 2.5, 3, 3.5, 2] #, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(x = pts_x, y = pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic4.svg')

# %%
pts_x = [1, 2, 1.5, 4, 3, 2.5, 2.1, 1.5, 3.5] #, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3, 2.5, 3, 3.5, 2, 2.5, 1.8, 4] #, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(x = pts_x, y = pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic5.svg')

# %%
pts_x = [1, 2, 1.5, 4, 3, 2.5, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3, 2.5, 3, 3.5, 2, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(x = pts_x, y = pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasicFull.svg')

# %%
for x,y in zip(pts_x, pts_y):
    print((x, y))
# Out:
# (1, 1)
# (2, 3)
# (1.5, 2.5)
# (4, 3)
# (3, 3.5)
# (2.5, 2)
# (2.1, 2.5)
# (1.5, 1.8)
# (3.5, 4)
# (1, 1.3)
# (2.6, 3.2)
# (3.4, 3)
# (1.3, 2)
# (0.5, 1)

# %%
cat = [0, 0, 1, 1, 0, 0, 1, 0, 1, 1, 0, 0, 1, 1]

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(x = pts_x, y = pts_y, s=200, hue=cat, alpha=0.7, edgecolor='black', palette={0: 'xkcd:crimson', 1: '#3d9f98'})
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.gca().get_legend().remove()
plt.tight_layout()
plt.savefig('08scatter_byHue.png')

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(x = pts_x, y = pts_y, s=200, style=cat, alpha=0.7, edgecolor='black', color='xkcd:crimson')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.gca().get_legend().remove()
plt.tight_layout()
plt.savefig('08scatter_byStyle.png')

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(x = pts_x, y = pts_y, size=cat, alpha=0.7, edgecolor='black', color='xkcd:crimson', sizes=[50, 300])
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.gca().get_legend().remove()
plt.tight_layout()
plt.savefig('08scatter_bySize.png')

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(x = pts_x, y = pts_y, size=cat, hue=cat, style=cat,
                alpha=0.7, edgecolor='black',  
                sizes=[100, 300],
                palette={0: 'xkcd:crimson', 1: '#3d9f98'}
               )
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.gca().get_legend().remove()
plt.tight_layout()
plt.savefig('08scatter_byAll.png')

# %%
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %% [markdown]
# ## Basics

# %%
sns.set_style('dark')

# %%
sns.scatterplot(x = diamonds.carat, y = diamonds.price);

# %%
sns.scatterplot(x='carat', y='price', data=diamonds);

# %%
sns.scatterplot(x='x', y='y', data=diamonds);

# %% [markdown]
# ## Semantic Variables

# %%
sns.set_style('darkgrid')

# %% [markdown]
# ### hue

# %%
sns.scatterplot(x='carat', y='price', hue='cut',
                data=diamonds
               );

# %%
sns.scatterplot(x='carat', y='price', hue='cut',
                data=diamonds,
                palette=['purple', '#55CCCC']
               );
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_7032\3721090327.py:1: UserWarning:
# The palette list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(x='carat', y='price', hue='cut',

# %%
sns.scatterplot(x='carat', y='price', hue='cut',
                data=diamonds,
                palette = ['purple', '#55CCCC'],
                hue_order=['Good', 'Premium']
               );

# %% [markdown]
# #### Continuous Variable

# %%
sns.scatterplot(x='carat', y='price', hue='depth',
                data=diamonds
               );

# %% [markdown]
# ### style

# %%
sns.scatterplot(x='carat', y='price', style='cut',
                data=diamonds,
                s=100
               );

# %% [markdown]
# ### size

# %%
sns.scatterplot(x='carat', y='price', size='cut',
                data=diamonds
               );

# %%
sns.scatterplot(x='carat', y='price', size='cut',
                data=diamonds, 
                sizes=[150, 50]
               );
# Out:
# C:\Users\xdxd2\AppData\Local\Temp\ipykernel_7032\340223160.py:1: UserWarning:
# The sizes list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(x='carat', y='price', size='cut',

# %%
sns.scatterplot(x='carat', y='price', size='depth',
                data=diamonds
               );

# %% [markdown]
# ### hue + style + size

# %%
sns.scatterplot(x='carat', y='price', 
                hue='cut', 
                style='cut',
                data=diamonds,
                s=100
               );

# %%
sns.scatterplot(x='carat', y='price', 
                hue='cut', 
                style='color',
                data=diamonds,
                s=100
               );

# %%
sns.scatterplot(x='carat', y='price', 
                hue='cut', 
                style='color',
                size='depth',
                data=diamonds);

# %% [markdown]
# ## Additional Styling

# %% [markdown]
# ### alpha

# %%
sns.scatterplot(x='carat', y='price', 
                data=diamonds,
                s=100,
                alpha=0.6
               );

# %% [markdown]
# ### marker styling
#
# Check the [matplotlib scatter](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html) and the [marker style docs](https://matplotlib.org/api/_as_gen/matplotlib.markers.MarkerStyle.html#matplotlib.markers.MarkerStyle) for more styling of the markers themselves

# %%
sns.scatterplot(x='carat', y='price', 
                data=diamonds, 
                s=200,
                marker='*'
               );

# %%
sns.scatterplot(x='carat', y='price', 
                data=diamonds, 
                s=200, 
                marker='*',
                edgecolor='black'
               );
