# %% [markdown]
# # S0 先修自測 (Pre-Course Self-Check)
#
# ## 目的
# 本課程假設你已掌握 Python 基礎語法（變數、list、dict、for、函式）。
# 請誠實完成以下 10 題自測，評估是否已準備好進入 12 小時 Python DA 課程。
#
# ## 自評標準
# - **8 題以上正確** → 你已準備好，直接進入 M1
# - **5-7 題正確** → 建議先複習 Python 基礎後再開始
# - **少於 5 題** → 建議先完成 Python 101 入門課程
#
# ## 作答方式
# 每題都有一個 `# TODO` 提示，請在該 cell 中撰寫程式碼，並確認輸出符合預期。
# 誠實作答，不要直接查答案。

# %% [markdown]
# ## Q1. 變數與型別
# 建立一個整數變數 `age = 25`、一個字串變數 `name = 'Alice'`，並使用 `type()` 印出兩者的型別。
#
# **預期輸出**: `<class 'int'>` 與 `<class 'str'>`

# %%
# TODO: 建立 age 與 name 並印出型別

# %% [markdown]
# ## Q2. List Comprehension
# 使用 list comprehension 產生 1 到 10 的平方數列表。
#
# **預期輸出**: `[1, 4, 9, 16, 25, 36, 49, 64, 81, 100]`

# %%
# TODO: squares = [...]

# %% [markdown]
# ## Q3. Dict 存取
# 給定 `student = {'name': 'Bob', 'score': 92}`，印出該學生的分數。
#
# **預期輸出**: `92`

# %%
# TODO: 取出 score 並印出

# %% [markdown]
# ## Q4. for-loop 與 enumerate
# 給定 `fruits = ['apple', 'banana', 'cherry']`，使用 `enumerate` 印出每個水果的索引與名稱，格式為 `0: apple`。
#
# **預期輸出**:
# ```
# 0: apple
# 1: banana
# 2: cherry
# ```

# %%
# TODO: 用 enumerate 迴圈印出

# %% [markdown]
# ## Q5. 函式定義與預設參數
# 定義一個函式 `greet(name, greeting='Hello')`，回傳 `'{greeting}, {name}!'`，並測試 `greet('Alice')` 與 `greet('Bob', 'Hi')`。
#
# **預期輸出**: `Hello, Alice!` 與 `Hi, Bob!`

# %%
# TODO: def greet(...)

# %% [markdown]
# ## Q6. 字串格式化 (f-string)
# 給定 `price = 1234.5678`，使用 f-string 印出保留 2 位小數的字串 `Price: 1234.57`。
#
# **預期輸出**: `Price: 1234.57`

# %%
# TODO: 使用 f-string 格式化

# %% [markdown]
# ## Q7. 檔案 I/O with open
# 使用 `with open(...)` 將字串 `'Hello, DA!'` 寫入 `test_output.txt`，然後讀取並印出內容。
#
# **預期輸出**: `Hello, DA!`

# %%
# TODO: with open(...) as f:

# %% [markdown]
# ## Q8. Tuple 解包
# 給定 `point = (3, 4)`，用 tuple unpacking 將其拆解為 `x` 與 `y` 並印出 `x=3, y=4`。
#
# **預期輸出**: `x=3, y=4`

# %%
# TODO: x, y = ...

# %% [markdown]
# ## Q9. 條件運算式 (Ternary)
# 給定 `score = 75`，使用單行條件運算式判斷是否及格（>= 60），印出 `'pass'` 或 `'fail'`。
#
# **預期輸出**: `pass`

# %%
# TODO: result = '...' if ... else '...'

# %% [markdown]
# ## Q10. Import 語句
# import `math` 模組，並印出 `math.pi` 四捨五入到小數點後 4 位。
#
# **預期輸出**: `3.1416`

# %%
# TODO: import math

# %% [markdown]
# ## 自我評估檢核表
#
# 請誠實勾選你能獨立完成（不查答案）的題目：
#
# - [ ] Q1 變數與型別
# - [ ] Q2 List comprehension
# - [ ] Q3 Dict 存取
# - [ ] Q4 for-loop 與 enumerate
# - [ ] Q5 函式與預設參數
# - [ ] Q6 f-string 格式化
# - [ ] Q7 檔案 I/O
# - [ ] Q8 Tuple 解包
# - [ ] Q9 條件運算式
# - [ ] Q10 Import 模組
#
# ### 結果判定
# - **8+ 題通過**: 恭喜，可以開始 M1 了
# - **5-7 題通過**: 建議先花 1-2 小時複習基礎
# - **<5 題通過**: 建議先完成 Python 101 入門教材再回來
#
# 加油，學習 Python DA 的旅程從這裡開始
